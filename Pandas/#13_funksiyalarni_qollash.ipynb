# %% [markdown]
# <a href="https://colab.research.google.com/github/nurbekdev/DataSciene/blob/main/%2313_funksiyalarni_qollash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt praktikum
# ## Ma'lumotlar tahlili. Pandas kutubxonasi
# ### Funksiyalarni qo'llash

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(3, 4), index = list('abc'), columns=['Olma', 'Anor', 'Qovun', 'Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -1.421398 -0.773700 -1.747883  0.738854
# b  1.862144  0.173601  0.963154 -0.009318
# c  0.297471 -0.322027 -0.290483 -0.732136

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.421398  0.773700  1.747883  0.738854
# b  1.862144  0.173601  0.963154  0.009318
# c  0.297471  0.322027  0.290483  0.732136

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -1.0  -1.0   -2.0    1.0
# b   2.0   0.0    1.0   -0.0
# c   0.0  -0.0   -0.0   -1.0

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -1.421398 -0.773700 -1.747883  0.738854
# b  1.862144  0.173601  0.963154 -0.009318
# c  0.297471 -0.322027 -0.290483 -0.732136
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8492517854893815792 = autoviz.get_df('df_8492517854893815792')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8492517854893815792, *['Olma'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# ...

# %%
df.mean()
# Out:
# Olma     0.246073
# Anor    -0.307375
# Qovun   -0.358404
# Anjir   -0.000867
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# a   -0.801032
# b    0.747395
# c   -0.261794
# dtype: float64

# %%
df.apply(np.abs)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.421398  0.773700  1.747883  0.738854
# b  1.862144  0.173601  0.963154  0.009318
# c  0.297471  0.322027  0.290483  0.732136

# %%
df.apply(sum, axis=1)
# Out:
# a   -3.204127
# b    2.989581
# c   -1.047174
# dtype: float64

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# Olma     3.283542
# Anor     0.947301
# Qovun    2.711037
# Anjir    1.470990
# dtype: float64

# %%
def foo(x):
  return pd.Series([x.min(), x.max()], index = ['min', 'max'])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun     Anjir
# min -1.421398 -0.773700 -1.747883 -0.732136
# max  1.862144  0.173601  0.963154  0.738854
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8839353850308672319 = autoviz.get_df('df_8839353850308672319')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8839353850308672319, *['Olma'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6628184768782457840 = autoviz.get_df('df_6628184768782457840')
#
# ...

# %%
df.applymap(lambda x: x*x)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  2.020371  0.598612  3.055095  0.545905
# b  3.467581  0.030137  0.927665  0.000087
# c  0.088489  0.103701  0.084380  0.536023
